# %% [markdown]
# https://www.huaweicloud.com/en-us/solution/bosch-iot-suite/
#
# ![IoT architecture](https://res-img3.huaweicloud.com/content/dam/cloudbu-site/archive/china/en-us/solution/industryspecific/bosch-iot-suite/images/solution_architecture2.png)

# %% [markdown]
# Bosch IoT Insights provides a cloud infrastructure, REST APIs and a web application user interface for storing, querying and isolating data for further investigation and needs. It is further based on state of the art technologies, such as MongoDB for example.
#
# **Important: after account creation, a Project Invitation must be accepted to visualize the Dashboard. Check your mail!**
